# %% [markdown]
# # [GD-08]도로 영역을 찾자! - 세그멘테이션 모델 만들기

# %% [markdown]
# #### 목차
#
# - (1) 라이브러리 import
# - (2) 데이터 준비 & 전처리
# - (3) 모델 구현
# - (4) 결과 분석

# %% [markdown]
# ### (1) 라이브러리 import

# %%
import os
import math
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize # Albumentation에서 다양한 augmentation 기법을 확률적으로 적용

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %% [markdown]
# ### (2) 데이터 준비 & 전처리

# %%
def build_augmentation(is_train=True):
    if is_train:
        return Compose([
            HorizontalFlip(p=0.5),
            RandomSizedCrop(
                min_max_height=(300, 370),
                w2h_ratio=370/1242,
                height=224,
                width=224,
                p=0.5
            ),
            Resize(
                width=224,
                height=224
            )
        ])
    return Compose([
        Resize(
            width=224,
            height=224
        )
    ])

# %%
dir_path=os.getenv('HOME')+'/aiffel/semantic_segmentation/data/training/'

augmentation = build_augmentation()
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i])
    image_data = {"image": image}
    resized = augmentation(**image_data, is_train=False)
    processed = augmentation(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])

plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
    '''
    KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
    '''
    
    def __init__(self,
                 dir_path,
                 batch_size=4,
                 img_size=(224, 224, 3),
                 output_size=(224, 224),
                 is_train=True,
                 augmentation=None):
        '''
        dir_path: dataset의 directory path입니다.
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''

        self.dir_path = dir_path
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size
        # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
        self.data = self.load_dataset()

    def load_dataset(self):
        # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
        # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
        input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
        label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
        input_images.sort()
        label_images.sort()
        assert len(input_images) == len(label_images)
        data = [_ for _ in zip(input_images, label_images)]

        if self.is_train:
            return data[:-30]
        return data[-30:]

    def __len__(self):
        # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, index):
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
            index*self.batch_size:
            (index + 1)*self.batch_size
        ]
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])

        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)
            _output = imread(output_path)
            _output = (_output == 7).astype(np.uint8)*1
            data = {
                "image": _input,
                "mask": _output,
            }
            augmented = self.augmentation(**data)
            inputs[i] = augmented["image"]/255
            outputs[i] = augmented["mask"]
            return inputs, outputs

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.data))
        if self.is_train == True:
            np.random.shuffle(self.indexes)
            return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)

train_generator = KittiGenerator(
    dir_path,
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path,
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ### (3) 모델 구현

# %%
def conv_batch(layer, filters):
    conv = Conv2D(filters, 3, activation='relu', padding='valid',kernel_initializer='he_normal')(layer)
    conv = Conv2D(filters, 3, activation='relu', padding='valid',kernel_initializer='he_normal')(conv)
    batch = BatchNormalization()(conv)
    
    return batch

# %%
def build_UNet(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)
    
    # Contracting path
    conv1 = conv_batch(inputs, 64)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = conv_batch(pool1, 128)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = conv_batch(pool2, 256)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = conv_batch(pool3, 512)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    batch5 = BatchNormalization()(conv5)
    
    # Expansive path
    up1 = Conv2D(512, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(batch5)) 
    merge1 = concatenate([conv4,up1])
    conv6 = conv_batch(merge1, 512)

    up2 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv6))
    crop_conv3 = tf.image.resize(conv3, (up2.shape[1], up2.shape[2]))
    merge2 = concatenate([crop_conv3,up2])
    conv7 = conv_batch(merge2, 256)

    up3 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv7))
    crop_conv2 = tf.image.resize(conv2, (up3.shape[1], up3.shape[2]))
    merge3 = concatenate([crop_conv2,up3])
    conv8 = conv_batch(merge3, 128)

    up4 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv8))
    crop_conv1 = tf.image.resize(conv1, (up4.shape[1], up4.shape[2]))
    merge4 = concatenate([crop_conv1, up4])
    conv9 = conv_batch(merge4, 64)
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)
    conv10 = tf.image.resize(conv10, (input_shape[0], input_shape[1]))

    model = Model(inputs = inputs, outputs = conv10)
    return model

# %%
UNet = build_UNet()
UNet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 222, 222, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 220, 220, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 220, 220, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 110, 110, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 108, 108, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 106, 106, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 106, 106, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 53, 53, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 51, 51, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 49, 49, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 49, 49, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 22, 22, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 20, 20, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 10, 10, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 20, 20, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 20, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 20, 1024) 0           batch_normalization_3[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 18, 18, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.image.resize (TFOpLambda)    (None, 32, 32, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           tf.image.resize[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 30, 30, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 256)  590080      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 56, 56, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_1 (TFOpLambda)  (None, 56, 56, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 128)  131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 256)  0           tf.image.resize_1[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 54, 54, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 52, 52, 128)  147584      conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 52, 52, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 104, 104, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_2 (TFOpLambda)  (None, 104, 104, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 104, 104, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 104, 104, 128 0           tf.image.resize_2[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 102, 102, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 100, 100, 64) 36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 100, 100, 2)  1154        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 100, 100, 1)  3           conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_3 (TFOpLambda)  (None, 224, 224, 1)  0           conv2d_22[0][0]
# ==================================================================================================
# Total params: 21,606,405
# Trainable params: 21,600,517
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
UNet.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy')
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
UNet.fit_generator(
    generator=train_generator,
    validation_data=test_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
)
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 43/43 [==============================] - 15s 142ms/step - loss: 0.8585 - val_loss: 0.7501
# Epoch 2/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.7471 - val_loss: 0.7063
# Epoch 3/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.7093 - val_loss: 0.7143
# Epoch 4/100
# 43/43 [==============================] - 6s 132ms/step - loss: 0.6942 - val_loss: 0.7357
# Epoch 5/100
# 43/43 [==============================] - 6s 133ms/step - loss: 0.6885 - val_loss: 0.6826
# Epoch 6/100
# 43/43 [==============================] - 6s 132ms/step - loss: 0.6822 - val_loss: 0.7255
# Epoch 7/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.6773 - val_loss: 0.7542
# Epoch 8/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6703 - val_loss: 0.8071
# Epoch 9/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6653 - val_loss: 0.7607
# Epoch 10/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6698 - val_loss: 0.8035
# Epoch 11/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6638 - val_loss: 0.7454
# Epoch 12/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6603 - val_loss: 0.7608
# Epoch 13/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6574 - val_loss: 0.7216
# Epoch 14/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6529 - val_loss: 0.6934
# Epoch 15/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6560 - val_loss: 1.2795
# Epoch 16/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6474 - val_loss: 1.1787
# Epoch 17/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6449 - val_loss: 0.6570
# Epoch 18/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6468 - val_loss: 0.7509
# Epoch 19/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6494 - val_loss: 0.6462
# Epoch 20/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6446 - val_loss: 0.6580
# Epoch 21/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6377 - val_loss: 0.6553
# Epoch 22/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6355 - val_loss: 0.6342
# Epoch 23/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6403 - val_loss: 0.8838
# Epoch 24/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.6350 - val_loss: 0.6962
# Epoch 25/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6334 - val_loss: 0.7921
# Epoch 26/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6323 - val_loss: 0.7427
# Epoch 27/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6293 - val_loss: 0.6445
# Epoch 28/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6294 - val_loss: 1.0814
# Epoch 29/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6271 - val_loss: 1.9269
# Epoch 30/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.6207 - val_loss: 0.6413
# Epoch 31/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6245 - val_loss: 1.0061
# Epoch 32/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6241 - val_loss: 0.9246
# Epoch 33/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6210 - val_loss: 0.7078
# Epoch 34/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6184 - val_loss: 0.6635
# Epoch 35/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6168 - val_loss: 0.6284
# Epoch 36/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6111 - val_loss: 0.6071
# Epoch 37/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6029 - val_loss: 0.6050
# Epoch 38/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6005 - val_loss: 0.6054
# Epoch 39/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5999 - val_loss: 0.7210
# Epoch 40/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6024 - val_loss: 0.6063
# Epoch 41/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6018 - val_loss: 0.6017
# Epoch 42/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5993 - val_loss: 0.6854
# Epoch 43/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5972 - val_loss: 0.6189
# Epoch 44/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5995 - val_loss: 0.6451
# Epoch 45/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5954 - val_loss: 0.5895
# Epoch 46/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5982 - val_loss: 0.6035
# Epoch 47/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5923 - val_loss: 0.6001
# Epoch 48/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5860 - val_loss: 0.6026
# Epoch 49/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5794 - val_loss: 0.5909
# Epoch 50/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5807 - val_loss: 0.7125
# Epoch 51/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5813 - val_loss: 0.5878
# Epoch 52/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.5834 - val_loss: 0.6856
# Epoch 53/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5805 - val_loss: 0.5875
# Epoch 54/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5796 - val_loss: 0.7436
# Epoch 55/100
# 43/43 [==============================] - 6s 131ms/step - loss: 0.5818 - val_loss: 0.7637
# Epoch 56/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5777 - val_loss: 0.5756
# Epoch 57/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5694 - val_loss: 0.5958
# Epoch 58/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5715 - val_loss: 0.5766
# Epoch 59/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5749 - val_loss: 0.5785
# Epoch 60/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5671 - val_loss: 0.6202
# Epoch 61/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5693 - val_loss: 1.5190
# Epoch 62/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5586 - val_loss: 0.6584
# Epoch 63/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5600 - val_loss: 0.5689
# Epoch 64/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5623 - val_loss: 0.6614
# Epoch 65/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5566 - val_loss: 0.5558
# Epoch 66/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5540 - val_loss: 0.5701
# Epoch 67/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5592 - val_loss: 0.5551
# Epoch 68/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5525 - val_loss: 0.5637
# Epoch 69/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5607 - val_loss: 0.5753
# Epoch 70/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5479 - val_loss: 0.6144
# Epoch 71/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5545 - val_loss: 0.9350
# Epoch 72/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5519 - val_loss: 0.8617
# Epoch 73/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5460 - val_loss: 0.8261
# Epoch 74/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5502 - val_loss: 1.3153
# Epoch 75/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5471 - val_loss: 0.5688
# Epoch 76/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5467 - val_loss: 0.5462
# Epoch 77/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5383 - val_loss: 0.6818
# Epoch 78/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5362 - val_loss: 0.5421
# Epoch 79/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5345 - val_loss: 0.5399
# Epoch 80/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5349 - val_loss: 0.5612
# Epoch 81/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5344 - val_loss: 0.5330
# Epoch 82/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5268 - val_loss: 0.7020
# Epoch 83/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5319 - val_loss: 0.5277
# Epoch 84/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5284 - val_loss: 0.5321
# Epoch 85/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5277 - val_loss: 0.5313
# Epoch 86/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5216 - val_loss: 0.5292
# Epoch 87/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5280 - val_loss: 0.5181
# Epoch 88/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5187 - val_loss: 0.5190
# Epoch 89/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5184 - val_loss: 0.5187
# Epoch 90/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5192 - val_loss: 0.5309
# Epoch 91/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5170 - val_loss: 0.5227
# Epoch 92/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5171 - val_loss: 0.5208
# Epoch 93/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5123 - val_loss: 0.5424
# Epoch 94/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5149 - val_loss: 0.5316
# Epoch 95/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5133 - val_loss: 0.5111
# Epoch 96/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5103 - val_loss: 0.5180
# Epoch 97/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5032 - val_loss: 0.5149
# Epoch 98/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.4986 - val_loss: 0.5188
# Epoch 99/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5050 - val_loss: 0.5440
# Epoch 100/100
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5022 - val_loss: 0.5842

# %%
UNet_model_path = '/content/drive/MyDrive/data/seg_model_unet.h5'
UNet.save(UNet_model_path)

# %% [markdown]
# - U-Net++

# %%
def build_UNet_plus(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)
    
    # Contracting path(Backbone)
    conv1 = conv_batch(inputs, 64)
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = conv_batch(pool1, 128)
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = conv_batch(pool2, 256)
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = conv_batch(pool3, 512)
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    batch5 = BatchNormalization()(conv5)
    
    
    # Re-designed skip pathways
    # conv1_1, conv2_1, conv3_1
    up_conv2 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2))
    skip_crop_conv1 = tf.image.resize(conv1, (up_conv2.shape[1], up_conv2.shape[2]))
    merge1_1 = concatenate([skip_crop_conv1, up_conv2])
    conv1_1 = conv_batch(merge1_1, 64)
    
    up_conv3 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv3))
    skip_crop_conv2 = tf.image.resize(conv2, (up_conv3.shape[1], up_conv3.shape[2]))
    merge2_1 = concatenate([skip_crop_conv2 , up_conv3])
    conv2_1 = conv_batch(merge2_1, 128)
    
    up_conv4 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv4))
    skip_crop_conv3 = tf.image.resize(conv3, (up_conv4.shape[1], up_conv4.shape[2]))
    merge3_1 = concatenate([skip_crop_conv3, up_conv4])
    conv3_1 = conv_batch(merge3_1, 256)
    
    # conv1_2, conv2_2
    up_conv2_1 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2_1))
    skip_crop_conv1 = tf.image.resize(conv1, (up_conv2_1.shape[1], up_conv2_1.shape[2]))
    skip_crop_conv1_1 = tf.image.resize(conv1_1, (up_conv2_1.shape[1], up_conv2_1.shape[2]))
    merge1_2 = concatenate([skip_crop_conv1, skip_crop_conv1_1, up_conv2_1])
    conv1_2 = conv_batch(merge1_2, 64)
    
    up_conv3_1 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv3_1))
    skip_crop_conv2 = tf.image.resize(conv2, (up_conv3_1.shape[1], up_conv3_1.shape[2]))
    skip_crop_conv2_1 = tf.image.resize(conv2_1, (up_conv3_1.shape[1], up_conv3_1.shape[2]))
    merge2_2 = concatenate([skip_crop_conv2, skip_crop_conv2_1, up_conv3_1])
    conv2_2 = conv_batch(merge2_2, 256)

    # conv1_3
    up_conv2_2 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv2_2))
    skip_crop_conv1 = tf.image.resize(conv1, (up_conv2_2.shape[1], up_conv2_2.shape[2]))
    skip_crop_conv1_1 = tf.image.resize(conv1_1, (up_conv2_2.shape[1], up_conv2_2.shape[2]))
    skip_crop_conv1_2 = tf.image.resize(conv1_2, (up_conv2_2.shape[1], up_conv2_2.shape[2]))
    merge1_3 = concatenate([skip_crop_conv1, skip_crop_conv1_1, skip_crop_conv1_2, up_conv2_2])
    conv1_3 = conv_batch(merge1_3, 64)
    
    
    # Expansive path
    up1 = Conv2D(512, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(batch5)) 
    merge1 = concatenate([conv4,up1])
    conv6 = conv_batch(merge1, 512)

    up2 = Conv2D(256, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv6))
    crop_conv3 = tf.image.resize(conv3, (up2.shape[1], up2.shape[2]))
    crop_conv3_1 = tf.image.resize(conv3_1, (up2.shape[1], up2.shape[2]))
    merge2 = concatenate([crop_conv3, crop_conv3_1, up2])
    conv7 = conv_batch(merge2, 256)

    up3 = Conv2D(128, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv7))
    crop_conv2 = tf.image.resize(conv2, (up3.shape[1], up3.shape[2]))
    crop_conv2_1 = tf.image.resize(conv2_1, (up3.shape[1], up3.shape[2]))
    crop_conv2_2 = tf.image.resize(conv2_2, (up3.shape[1], up3.shape[2]))
    merge3 = concatenate([crop_conv2, crop_conv2_1, crop_conv2_2, up3])
    conv8 = conv_batch(merge3, 128)

    up4 = Conv2D(64, 2, activation='relu', padding='same',kernel_initializer='he_normal')(UpSampling2D(size = (2,2))(conv8))
    crop_conv1 = tf.image.resize(conv1, (up4.shape[1], up4.shape[2]))
    crop_conv1_1 = tf.image.resize(conv1_1, (up4.shape[1], up4.shape[2]))
    crop_conv1_2 = tf.image.resize(conv1_2, (up4.shape[1], up4.shape[2]))
    crop_conv1_3 = tf.image.resize(conv1_3, (up4.shape[1], up4.shape[2]))
    merge4 = concatenate([crop_conv1, crop_conv1_1, crop_conv1_2, crop_conv1_3, up4])
    conv9 = conv_batch(merge4, 64)
    conv9 = Conv2D(2, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)
    conv10 = tf.image.resize(conv10, (input_shape[0], input_shape[1]))

    model = Model(inputs = inputs, outputs = conv10)
    
    return model

# %%
UNet_plus = build_UNet_plus()
UNet_plus.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 222, 222, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 220, 220, 64) 36928       conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 220, 220, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 110, 110, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 108, 108, 128 73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 106, 106, 128 147584      conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 106, 106, 128 512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 53, 53, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 51, 51, 256)  295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 49, 49, 256)  590080      conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 49, 49, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 22, 22, 512)  1180160     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 20, 20, 512)  2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 10, 10, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 1024) 4096        conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 20, 20, 1024) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 40, 40, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 20, 20, 512)  2097664     up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 98, 98, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_6 (TFOpLambda)  (None, 40, 40, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 40, 40, 256)  524544      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 20, 20, 1024) 0           batch_normalization_12[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 212, 212, 128 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_5 (TFOpLambda)  (None, 98, 98, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 98, 98, 128)  131200      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 40, 40, 512)  0           tf.image.resize_6[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 18, 18, 512)  4719104     concatenate_10[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_4 (TFOpLambda)  (None, 212, 212, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 212, 212, 64) 32832       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 98, 98, 256)  0           tf.image.resize_5[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 38, 38, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 212, 212, 128 0           tf.image.resize_4[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 96, 96, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 36, 36, 256)  590080      conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 512)  2048        conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 210, 210, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 94, 94, 128)  147584      conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 36, 36, 256)  1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 32, 32, 512)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 208, 208, 64) 36928       conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 94, 94, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 72, 72, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_14 (TFOpLambda) (None, 32, 32, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_15 (TFOpLambda) (None, 32, 32, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 256)  524544      up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 208, 208, 64) 256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 188, 188, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_9 (TFOpLambda)  (None, 72, 72, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_10 (TFOpLambda) (None, 72, 72, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 72, 72, 256)  262400      up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 32, 32, 768)  0           tf.image.resize_14[0][0]
#                                                                  tf.image.resize_15[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_7 (TFOpLambda)  (None, 188, 188, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_8 (TFOpLambda)  (None, 188, 188, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 188, 188, 64) 32832       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 72, 72, 512)  0           tf.image.resize_9[0][0]
#                                                                  tf.image.resize_10[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 30, 30, 256)  1769728     concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 188, 188, 192 0           tf.image.resize_7[0][0]
#                                                                  tf.image.resize_8[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 70, 70, 256)  1179904     concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 28, 28, 256)  590080      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 186, 186, 64) 110656      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 68, 68, 256)  590080      conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 256)  1024        conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 184, 184, 64) 36928       conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 68, 68, 256)  1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 56, 56, 256)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 184, 184, 64) 256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 136, 136, 256 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_16 (TFOpLambda) (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_17 (TFOpLambda) (None, 56, 56, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_18 (TFOpLambda) (None, 56, 56, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 56, 56, 128)  131200      up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_11 (TFOpLambda) (None, 136, 136, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_12 (TFOpLambda) (None, 136, 136, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_13 (TFOpLambda) (None, 136, 136, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 136, 136, 64) 65600       up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 56, 56, 640)  0           tf.image.resize_16[0][0]
#                                                                  tf.image.resize_17[0][0]
#                                                                  tf.image.resize_18[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 136, 136, 256 0           tf.image.resize_11[0][0]
#                                                                  tf.image.resize_12[0][0]
#                                                                  tf.image.resize_13[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 54, 54, 128)  737408      concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 134, 134, 64) 147520      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 52, 52, 128)  147584      conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 132, 132, 64) 36928       conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 52, 52, 128)  512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 132, 132, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 104, 104, 128 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_19 (TFOpLambda) (None, 104, 104, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_20 (TFOpLambda) (None, 104, 104, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_21 (TFOpLambda) (None, 104, 104, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_22 (TFOpLambda) (None, 104, 104, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 104, 104, 64) 32832       up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 104, 104, 320 0           tf.image.resize_19[0][0]
#                                                                  tf.image.resize_20[0][0]
#                                                                  tf.image.resize_21[0][0]
#                                                                  tf.image.resize_22[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 102, 102, 64) 184384      concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 100, 100, 64) 36928       conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 100, 100, 64) 256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 100, 100, 2)  1154        batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 100, 100, 1)  3           conv2d_62[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_23 (TFOpLambda) (None, 224, 224, 1)  0           conv2d_63[0][0]
# ==================================================================================================
# Total params: 28,227,269
# Trainable params: 28,219,717
# Non-trainable params: 7,552
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(UNet_plus, to_file='/content/drive/MyDrive/data/U-Net++.png')

# %%
UNet_plus.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy')
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
UNet_plus.fit_generator(
    generator=train_generator,
    validation_data=test_generator,
    steps_per_epoch=len(train_generator),
    epochs=100,
)
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 43/43 [==============================] - 29s 419ms/step - loss: 0.6346 - val_loss: 0.6895
# Epoch 2/100
# 43/43 [==============================] - 18s 407ms/step - loss: 0.6005 - val_loss: 0.6784
# Epoch 3/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5800 - val_loss: 0.6479
# Epoch 4/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5860 - val_loss: 0.6852
# Epoch 5/100
# 43/43 [==============================] - 18s 408ms/step - loss: 0.5665 - val_loss: 0.6185
# Epoch 6/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5729 - val_loss: 0.3243
# Epoch 7/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5719 - val_loss: 0.6026
# Epoch 8/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5674 - val_loss: 0.5674
# Epoch 9/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5574 - val_loss: 0.5620
# Epoch 10/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5656 - val_loss: 0.5780
# Epoch 11/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5560 - val_loss: 0.5743
# Epoch 12/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5489 - val_loss: 0.5509
# Epoch 13/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5498 - val_loss: 0.6952
# Epoch 14/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5509 - val_loss: 0.4202
# Epoch 15/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5452 - val_loss: 0.5799
# Epoch 16/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5379 - val_loss: 0.6238
# Epoch 17/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5478 - val_loss: 0.3141
# Epoch 18/100
# 43/43 [==============================] - 17s 405ms/step - loss: 0.5346 - val_loss: 0.6340
# Epoch 19/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5499 - val_loss: 0.4768
# Epoch 20/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5423 - val_loss: 0.3097
# Epoch 21/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5365 - val_loss: 0.9610
# Epoch 22/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5346 - val_loss: 0.5601
# Epoch 23/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5333 - val_loss: 0.5548
# Epoch 24/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5278 - val_loss: 0.5454
# Epoch 25/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5243 - val_loss: 0.6829
# Epoch 26/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5205 - val_loss: 0.5893
# Epoch 27/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5213 - val_loss: 0.2620
# Epoch 28/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5268 - val_loss: 0.4647
# Epoch 29/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5194 - val_loss: 0.5827
# Epoch 30/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5116 - val_loss: 0.5199
# Epoch 31/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5105 - val_loss: 0.5252
# Epoch 32/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5151 - val_loss: 0.5978
# Epoch 33/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5050 - val_loss: 0.6219
# Epoch 34/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5114 - val_loss: 0.5571
# Epoch 35/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5089 - val_loss: 0.5155
# Epoch 36/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5044 - val_loss: 0.5228
# Epoch 37/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5031 - val_loss: 0.5243
# Epoch 38/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5003 - val_loss: 0.9518
# Epoch 39/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.5110 - val_loss: 0.6610
# Epoch 40/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4962 - val_loss: 0.4755
# Epoch 41/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4968 - val_loss: 0.2792
# Epoch 42/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4957 - val_loss: 0.5537
# Epoch 43/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.5007 - val_loss: 0.9034
# Epoch 44/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4896 - val_loss: 0.5106
# Epoch 45/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4863 - val_loss: 0.4924
# Epoch 46/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4902 - val_loss: 0.6825
# Epoch 47/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4905 - val_loss: 0.5308
# Epoch 48/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4856 - val_loss: 0.6216
# Epoch 49/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4786 - val_loss: 0.4975
# Epoch 50/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4811 - val_loss: 0.5199
# Epoch 51/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4857 - val_loss: 0.5126
# Epoch 52/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4832 - val_loss: 0.5917
# Epoch 53/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4833 - val_loss: 0.7783
# Epoch 54/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4706 - val_loss: 0.5690
# Epoch 55/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4850 - val_loss: 0.6817
# Epoch 56/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4756 - val_loss: 0.8864
# Epoch 57/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4763 - val_loss: 0.4796
# Epoch 58/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4849 - val_loss: 0.4778
# Epoch 59/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4677 - val_loss: 0.4774
# Epoch 60/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4648 - val_loss: 0.4793
# Epoch 61/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4706 - val_loss: 0.5039
# Epoch 62/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4691 - val_loss: 0.4658
# Epoch 63/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4675 - val_loss: 0.4978
# Epoch 64/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4673 - val_loss: 2.9355
# Epoch 65/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4670 - val_loss: 0.6149
# Epoch 66/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4587 - val_loss: 0.6406
# Epoch 67/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4540 - val_loss: 0.4701
# Epoch 68/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4545 - val_loss: 0.6528
# Epoch 69/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4681 - val_loss: 0.4706
# Epoch 70/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4489 - val_loss: 0.5697
# Epoch 71/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4653 - val_loss: 0.6031
# Epoch 72/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4575 - val_loss: 0.5242
# Epoch 73/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4485 - val_loss: 0.5235
# Epoch 74/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4518 - val_loss: 0.4940
# Epoch 75/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4505 - val_loss: 0.4987
# Epoch 76/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4387 - val_loss: 0.5827
# Epoch 77/100
# 43/43 [==============================] - 17s 404ms/step - loss: 0.4475 - val_loss: 0.5182
# Epoch 78/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4492 - val_loss: 0.1585
# Epoch 79/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4446 - val_loss: 0.7343
# Epoch 80/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4367 - val_loss: 0.4575
# Epoch 81/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4360 - val_loss: 0.6174
# Epoch 82/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4368 - val_loss: 0.4650
# Epoch 83/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4324 - val_loss: 0.6374
# Epoch 84/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4277 - val_loss: 0.7018
# Epoch 85/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4313 - val_loss: 0.5193
# Epoch 86/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4349 - val_loss: 0.5669
# Epoch 87/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4260 - val_loss: 0.4417
# Epoch 88/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4331 - val_loss: 0.9574
# Epoch 89/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4278 - val_loss: 0.7166
# Epoch 90/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4246 - val_loss: 0.5813
# Epoch 91/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4326 - val_loss: 0.4793
# Epoch 92/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4286 - val_loss: 0.5408
# Epoch 93/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4240 - val_loss: 0.6566
# Epoch 94/100
# 43/43 [==============================] - 17s 402ms/step - loss: 0.4166 - val_loss: 0.5224
# Epoch 95/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4193 - val_loss: 0.4544
# Epoch 96/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4200 - val_loss: 0.5619
# Epoch 97/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4233 - val_loss: 0.5545
# Epoch 98/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4110 - val_loss: 0.4726
# Epoch 99/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4134 - val_loss: 0.4208
# Epoch 100/100
# 43/43 [==============================] - 17s 403ms/step - loss: 0.4113 - val_loss: 0.4644

# %%
UNet_plus_model_path = '/content/drive/MyDrive/data/seg_model_unet_plus.h5'
UNet.save(UNet_plus_model_path)

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    
    plt.figure(figsize=(12, 20))
    plt.imshow(output)

    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %% [markdown]
# ### (4) 결과 분석

# %%
i = 1
output, prediction, target = get_output(
     UNet, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.000708

# %%
i = 1
output, prediction, target = get_output(
     UNet_plus, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.900548

# %% [markdown]
# # 회고
#
# ### 목표
# |번호|평가문항|상세기준|
# |:---:|---|---|
# |1|U-Net을 통한 세그멘테이션 작업이 정상적으로 진행되었는가?|KITTI 데이터셋 구성, U-Net 모델 훈련, 결과물 시각화의 한 사이클이 정상 수행되어 세그멘테이션 결과 이미지를 제출하였다.|
# |2|U-Net++ 모델이 성공적으로 구현되었는가?|U-Net++ 모델을 스스로 구현하여 학습 진행 후 세그멘테이션 결과까지 정상 진행되었다.|
# |3|U-Net과 U-Net++ 두 모델의 성능이 정량적/정성적으로 잘 비교되었는가?|U-Net++ 의 세그멘테이션 결과 사진과 IoU 계산치를 U-Net과 비교하여 우월함을 확인하였다.|
#
# <br>
#
# - U-Net 과 U-Net++ 를 학습하고 성능 차이를 비교해 봤다.U-Net은 Segmentation 을 목적으로 제안된 모델로 의료 분야의 이미지를 다루기 위한 목적으로 제안되었는데 U-Net++ 모델 구현은 역시나 어려웠다. 논문을 정독하고 학습에 반영하기엔 시간이 너무 부족했다.
# <br>
#
# - IoU 결과값으로 U-Net++ 이 0.90 라는 것은 성능이 괜찮다는걸 의미하는 것 같은데 U-Net 이 제대로 학습이 되지 않아 IoU 값이 0.0007 이라 두 모델을 비교하기에는 적합하지 않은것 같다. 세그멘테이션이 정상적으로 되었다고 해도 U-Net 의 IoU 값은 U-Net++ 보다는 낮았을 것이다. 다시 고쳐서 epoch 을 돌리기엔 시간이 부족하여 아쉽다.
#
#
# - 세그멘테이션 결과를 시각화하여 U-Net++ 가 도로 영역을 비교적 잘 찾아낸 것을 볼수 있으나 경개가 아주 매끄럽지는 않다. U-Net 은 IoU 가 0.0007 인것을 봐도 알수 있듯 세크멘데이션이 되지 않음을 확인할 수 있다.
